# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("./data/Stock.csv")

# %%
data
# Out:
#     Day       Open       High        Low      Close  Adj Close  Volume
# 0     1  16.770000  17.559999  16.730000  17.010000  16.934999  271700
# 1     2  17.100000  17.469999  16.950001  17.200001  17.200001  229800
# 2     3  17.059999  17.230000  16.870001  17.049999  17.049999  146300
# 3     4  16.900000  17.330000  16.900000  16.920000  16.920000  139700
# 4     5  16.969999  16.990000  16.200001  16.290001  16.290001  216600
# 5     6  16.240000  16.530001  16.110001  16.480000  16.480000  115700
# 6     7  16.389999  16.709999  16.320000  16.610001  16.610001   93000
# 7     8  16.549999  16.629999  16.129999  16.139999  16.139999  128600
# 8     9  15.990000  16.320000  15.630000  15.670000  15.670000  171100
# 9    10  15.770000  16.600000  15.770000  16.410000  16.410000  121700
# 10   11  16.389999  16.389999  16.100000  16.150000  16.150000   32300
# 11   12  16.330000  16.480000  16.059999  16.360001  16.360001  143000
# ...

# %%
print(data['Close'].plot())
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
names = ["age","workclass","fnlwgt","education","edu-num","marital-status","occupation","relationship","race","sex","cap-gain","cap-loss","hour/week","country","salary"]

# %%
adult_data = pd.read_csv('./data/adult.data.csv', header=None, names=names)

# %%
adult_data.head()
# Out:
#    age          workclass  fnlwgt   education  edu-num       marital-status  \
# 0   39          State-gov   77516   Bachelors       13        Never-married
# 1   50   Self-emp-not-inc   83311   Bachelors       13   Married-civ-spouse
# 2   38            Private  215646     HS-grad        9             Divorced
# 3   53            Private  234721        11th        7   Married-civ-spouse
# 4   28            Private  338409   Bachelors       13   Married-civ-spouse
#
#            occupation    relationship    race      sex  cap-gain  cap-loss  \
# 0        Adm-clerical   Not-in-family   White     Male      2174         0
# 1     Exec-managerial         Husband   White     Male         0         0
# 2   Handlers-cleaners   Not-in-family   White     Male         0         0
# 3   Handlers-cleaners         Husband   Black     Male         0         0
# 4      Prof-specialty            Wife   Black   Female         0         0
#
#    hour/week         country  salary
# ...

# %%
# retrieve all values from my data frame. 
adult_data.values
# Out:
# array([[39, ' State-gov', 77516, ..., 40, ' United-States', ' <=50K'],
#        [50, ' Self-emp-not-inc', 83311, ..., 13, ' United-States',
#         ' <=50K'],
#        [38, ' Private', 215646, ..., 40, ' United-States', ' <=50K'],
#        ...,
#        [58, ' Private', 151910, ..., 40, ' United-States', ' <=50K'],
#        [22, ' Private', 201490, ..., 20, ' United-States', ' <=50K'],
#        [52, ' Self-emp-inc', 287927, ..., 40, ' United-States', ' >50K']],
#       dtype=object)

# %%
# check my index stats
adult_data.index
# Out:
# RangeIndex(start=0, stop=32561, step=1)

# %%
# check the shape of my data frame
data.shape
# Out:
# (20, 7)

# %%
# check the size of my dataframe 
data.size
# Out:
# 140

# %%
# check the data types of my dataframes
adult_data.dtypes
# Out:
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# edu-num            int64
# marital-status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# cap-gain           int64
# cap-loss           int64
# hour/week          int64
# country           object
# salary            object
# dtype: object

# %%
# check the info of my dataFrame
# Print a concise summary of a DataFrame
adult_data.info
# Out:
# <bound method DataFrame.info of        age          workclass  fnlwgt      education  edu-num  \
# 0       39          State-gov   77516      Bachelors       13
# 1       50   Self-emp-not-inc   83311      Bachelors       13
# 2       38            Private  215646        HS-grad        9
# 3       53            Private  234721           11th        7
# 4       28            Private  338409      Bachelors       13
# 5       37            Private  284582        Masters       14
# 6       49            Private  160187            9th        5
# 7       52   Self-emp-not-inc  209642        HS-grad        9
# 8       31            Private   45781        Masters       14
# 9       42            Private  159449      Bachelors       13
# 10      37            Private  280464   Some-college       10
# 11      30          State-gov  141297      Bachelors       13
# 12      23            Private  122272      Bachelors       13
# 13      32            Private  205019     Assoc-acdm       12
# ...

# %%
# get the data types counts from my dataFrame
adult_data.get_dtype_counts()
# Out:
# int64     6
# object    9
# dtype: int64

# %%
# check the axes of my dataFrame
adult_data.axes
# Out:
# [RangeIndex(start=0, stop=32561, step=1),
#  Index(['age', 'workclass', 'fnlwgt', 'education', 'edu-num', 'marital-status',
#         'occupation', 'relationship', 'race', 'sex', 'cap-gain', 'cap-loss',
#         'hour/week', 'country', 'salary'],
#        dtype='object')]

# %%
# check my dataFrame description
#Generate descriptive statistics that summarize the central tendency, dispersion and shape of a dataset’s distribution, excluding NaN values.
adult_data.describe
# Out:
# <bound method NDFrame.describe of        age          workclass  fnlwgt      education  edu-num  \
# 0       39          State-gov   77516      Bachelors       13
# 1       50   Self-emp-not-inc   83311      Bachelors       13
# 2       38            Private  215646        HS-grad        9
# 3       53            Private  234721           11th        7
# 4       28            Private  338409      Bachelors       13
# 5       37            Private  284582        Masters       14
# 6       49            Private  160187            9th        5
# 7       52   Self-emp-not-inc  209642        HS-grad        9
# 8       31            Private   45781        Masters       14
# 9       42            Private  159449      Bachelors       13
# 10      37            Private  280464   Some-college       10
# 11      30          State-gov  141297      Bachelors       13
# 12      23            Private  122272      Bachelors       13
# 13      32            Private  205019     Assoc-acdm       12
# ...

# %% [markdown]
# ## adding data on top of an exisiting dataFrame

# %%
adult_data['species'] = "mammal"

# %%
adult_data["mammal_type"] = "Human Being"

# %%
adult_data.head()
# Out:
#    age          workclass  fnlwgt   education  edu-num       marital-status  \
# 0   39          State-gov   77516   Bachelors       13        Never-married
# 1   50   Self-emp-not-inc   83311   Bachelors       13   Married-civ-spouse
# 2   38            Private  215646     HS-grad        9             Divorced
# 3   53            Private  234721        11th        7   Married-civ-spouse
# 4   28            Private  338409   Bachelors       13   Married-civ-spouse
#
#            occupation    relationship    race      sex  cap-gain  cap-loss  \
# 0        Adm-clerical   Not-in-family   White     Male      2174         0
# 1     Exec-managerial         Husband   White     Male         0         0
# 2   Handlers-cleaners   Not-in-family   White     Male         0         0
# 3   Handlers-cleaners         Husband   Black     Male         0         0
# 4      Prof-specialty            Wife   Black   Female         0         0
#
#    hour/week         country  salary species  mammal_type
# ...

# %%
mean_age = adult_data['age'].mean()

# %%
mean_age
# Out:
# 38.58164675532078

# %%
popular_occupation = adult_data['occupation'].agg('max')

# %%
popular_occupation.strip()
# Out:
# 'Transport-moving'

# %%
adult_data['age'].plot()

# %%
# manipulating data columns
age_in_months = adult_data['age'] * 12

# %%
average_hrs_worked = adult_data['hour/week'].mean()

# %%
average_hrs_worked
# Out:
# 40.437455852092995

# %%
# returning a column as series with bracket approach
adult_data['marital-status'].agg('max').strip()
# Out:
# 'Widowed'

# %%
# the dot approach only works where there are no spaces
adult_data.education.agg('max').strip()
# Out:
# 'Some-college'

# %%
# to return multiple columns I must use bracket notation
selected_df = adult_data[['age', 'education','salary']]

# %%
selected_df.head()
# Out:
#    age   education  salary
# 0   39   Bachelors   <=50K
# 1   50   Bachelors   <=50K
# 2   38     HS-grad   <=50K
# 3   53        11th   <=50K
# 4   28   Bachelors   <=50K

# %%
# conditional filters 
millineal_ages = [23,38]
male = adult_data['sex'] == " Male"
adult_data[male]
# Out:
#        age          workclass  fnlwgt      education  edu-num  \
# 0       39          State-gov   77516      Bachelors       13
# 1       50   Self-emp-not-inc   83311      Bachelors       13
# 2       38            Private  215646        HS-grad        9
# 3       53            Private  234721           11th        7
# 7       52   Self-emp-not-inc  209642        HS-grad        9
# 9       42            Private  159449      Bachelors       13
# 10      37            Private  280464   Some-college       10
# 11      30          State-gov  141297      Bachelors       13
# 13      32            Private  205019     Assoc-acdm       12
# 14      40            Private  121772      Assoc-voc       11
# 15      34            Private  245487        7th-8th        4
# 16      25   Self-emp-not-inc  176756        HS-grad        9
# 17      32            Private  186824        HS-grad        9
# 18      38            Private   28887           11th        7
# ...

# %%
female = adult_data[adult_data["sex"] == " Female"]

# %%
female.head()
# Out:
#     age workclass  fnlwgt   education  edu-num          marital-status  \
# 4    28   Private  338409   Bachelors       13      Married-civ-spouse
# 5    37   Private  284582     Masters       14      Married-civ-spouse
# 6    49   Private  160187         9th        5   Married-spouse-absent
# 8    31   Private   45781     Masters       14           Never-married
# 12   23   Private  122272   Bachelors       13           Never-married
#
#           occupation    relationship    race      sex  cap-gain  cap-loss  \
# 4     Prof-specialty            Wife   Black   Female         0         0
# 5    Exec-managerial            Wife   White   Female         0         0
# 6      Other-service   Not-in-family   Black   Female         0         0
# 8     Prof-specialty   Not-in-family   White   Female     14084         0
# 12      Adm-clerical       Own-child   White   Female         0         0
#
#     hour/week         country  salary
# 4          40            Cuba   <=50K
# ...

# %%
# how to filter with multiple conditions

conn1 = adult_data['age'] >= 23
conn2 = adult_data['age']<= 38

# %%
millineals = adult_data[conn1 & conn2]

# %%
millineals.relationship.agg('max').strip()
# Out:
# 'Wife'

# %%
# filtering a dataset with isin, pass it a list with filter values
never_married = millineals['marital-status'].isin([" Never-married"])

# %%
millineals[never_married]['age'].mean()
# Out:
# 28.44393104673894

# %%
millineals[millineals.relationship.isin([" Own-child"])]['race'].agg("max")
# Out:
# ' White'
