# %%
# %%HTML
# <style type="text/css">
#     table.dataframe td, table.dataframe th {
#         border-style: solid;
#         border-width: thin;
#     }
# </style>
# Out:
# <style type="text/css">
#     table.dataframe td, table.dataframe th {
#         border-style: solid;
#         border-width: thin;
#     }
# </style>

# %% [markdown]
# # Working with Text Data

# %%
import pandas as pd

# %%
data = pd.read_csv('SMSSpamCollection',sep='\t', header=None, names=['status','msg'])

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.head()
# Out:
#   status                                                msg
# 0    ham  Go until jurong point, crazy.. Available only ...
# 1    ham                      Ok lar... Joking wif u oni...
# 2   spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3    ham  U dun say so early hor... U c already then say...
# 4    ham  Nah I don't think he goes to usf, he lives aro...

# %% [markdown]
# # Upper , Lower, Title, Len

# %%
data.head()
# Out:
#   status                                                msg
# 0    ham  Go until jurong point, crazy.. Available only ...
# 1    ham                      Ok lar... Joking wif u oni...
# 2   spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3    ham  U dun say so early hor... U c already then say...
# 4    ham  Nah I don't think he goes to usf, he lives aro...

# %%
data['status'].upper()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-2a5a0e697824> in <module>()
# ----> 1 data['status'].upper()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'upper'

# %%
data['status'].str.upper()
# Out:
# 0        HAM
# 1        HAM
# 2       SPAM
# 3        HAM
# 4        HAM
# 5       SPAM
# 6        HAM
# 7        HAM
# 8       SPAM
# 9       SPAM
# 10       HAM
# 11      SPAM
# 12      SPAM
# 13       HAM
# 14       HAM
# 15      SPAM
# 16       HAM
# 17       HAM
# 18       HAM
# 19      SPAM
# 20       HAM
# 21       HAM
# 22       HAM
# 23       HAM
# 24       HAM
# 25       HAM
# 26       HAM
# 27       HAM
# 28       HAM
# 29       HAM
#         ...
# 5542     HAM
# 5543     HAM
# 5544     HAM
# 5545     HAM
# 5546     HAM
# 5547    SPAM
# 5548     HAM
# 5549     HAM
# 5550     HAM
# 5551     HAM
# 5552     HAM
# 5553     HAM
# 5554     HAM
# 5555     HAM
# 5556     HAM
# 5557     HAM
# 5558     HAM
# 5559     HAM
# 5560     HAM
# 5561     HAM
# 5562     HAM
# 5563     HAM
# 5564     HAM
# 5565     HAM
# 5566    SPAM
# 5567    SPAM
# 5568     HAM
# 5569     HAM
# 5570     HAM
# 5571     HAM
# Name: status, Length: 5572, dtype: object

# %%
data['msg'].str.upper()
# Out:
# 0       GO UNTIL JURONG POINT, CRAZY.. AVAILABLE ONLY ...
# 1                           OK LAR... JOKING WIF U ONI...
# 2       FREE ENTRY IN 2 A WKLY COMP TO WIN FA CUP FINA...
# 3       U DUN SAY SO EARLY HOR... U C ALREADY THEN SAY...
# 4       NAH I DON'T THINK HE GOES TO USF, HE LIVES ARO...
# 5       FREEMSG HEY THERE DARLING IT'S BEEN 3 WEEK'S N...
# 6       EVEN MY BROTHER IS NOT LIKE TO SPEAK WITH ME. ...
# 7       AS PER YOUR REQUEST 'MELLE MELLE (ORU MINNAMIN...
# 8       WINNER!! AS A VALUED NETWORK CUSTOMER YOU HAVE...
# 9       HAD YOUR MOBILE 11 MONTHS OR MORE? U R ENTITLE...
# 10      I'M GONNA BE HOME SOON AND I DON'T WANT TO TAL...
# 11      SIX CHANCES TO WIN CASH! FROM 100 TO 20,000 PO...
# 12      URGENT! YOU HAVE WON A 1 WEEK FREE MEMBERSHIP ...
# 13      I'VE BEEN SEARCHING FOR THE RIGHT WORDS TO THA...
# 14                    I HAVE A DATE ON SUNDAY WITH WILL!!
# 15      XXXMOBILEMOVIECLUB: TO USE YOUR CREDIT, CLICK ...
# ...

# %%
data['status'].str.upper().str.lower()
# Out:
# 0        ham
# 1        ham
# 2       spam
# 3        ham
# 4        ham
# 5       spam
# 6        ham
# 7        ham
# 8       spam
# 9       spam
# 10       ham
# 11      spam
# 12      spam
# 13       ham
# 14       ham
# 15      spam
# 16       ham
# 17       ham
# 18       ham
# 19      spam
# 20       ham
# 21       ham
# 22       ham
# 23       ham
# 24       ham
# 25       ham
# 26       ham
# 27       ham
# 28       ham
# 29       ham
#         ...
# 5542     ham
# 5543     ham
# 5544     ham
# 5545     ham
# 5546     ham
# 5547    spam
# 5548     ham
# 5549     ham
# 5550     ham
# 5551     ham
# 5552     ham
# 5553     ham
# 5554     ham
# 5555     ham
# 5556     ham
# 5557     ham
# 5558     ham
# 5559     ham
# 5560     ham
# 5561     ham
# 5562     ham
# 5563     ham
# 5564     ham
# 5565     ham
# 5566    spam
# 5567    spam
# 5568     ham
# 5569     ham
# 5570     ham
# 5571     ham
# Name: status, Length: 5572, dtype: object

# %%
data['status'].str.title()
# Out:
# 0        Ham
# 1        Ham
# 2       Spam
# 3        Ham
# 4        Ham
# 5       Spam
# 6        Ham
# 7        Ham
# 8       Spam
# 9       Spam
# 10       Ham
# 11      Spam
# 12      Spam
# 13       Ham
# 14       Ham
# 15      Spam
# 16       Ham
# 17       Ham
# 18       Ham
# 19      Spam
# 20       Ham
# 21       Ham
# 22       Ham
# 23       Ham
# 24       Ham
# 25       Ham
# 26       Ham
# 27       Ham
# 28       Ham
# 29       Ham
#         ...
# 5542     Ham
# 5543     Ham
# 5544     Ham
# 5545     Ham
# 5546     Ham
# 5547    Spam
# 5548     Ham
# 5549     Ham
# 5550     Ham
# 5551     Ham
# 5552     Ham
# 5553     Ham
# 5554     Ham
# 5555     Ham
# 5556     Ham
# 5557     Ham
# 5558     Ham
# 5559     Ham
# 5560     Ham
# 5561     Ham
# 5562     Ham
# 5563     Ham
# 5564     Ham
# 5565     Ham
# 5566    Spam
# 5567    Spam
# 5568     Ham
# 5569     Ham
# 5570     Ham
# 5571     Ham
# Name: status, Length: 5572, dtype: object

# %%
data['status'].str.len()
# Out:
# 0       3
# 1       3
# 2       4
# 3       3
# 4       3
# 5       4
# 6       3
# 7       3
# 8       4
# 9       4
# 10      3
# 11      4
# 12      4
# 13      3
# 14      3
# 15      4
# 16      3
# 17      3
# 18      3
# 19      4
# 20      3
# 21      3
# 22      3
# 23      3
# 24      3
# 25      3
# 26      3
# 27      3
# 28      3
# 29      3
#        ..
# 5542    3
# 5543    3
# 5544    3
# 5545    3
# 5546    3
# 5547    4
# 5548    3
# 5549    3
# 5550    3
# 5551    3
# 5552    3
# 5553    3
# 5554    3
# 5555    3
# 5556    3
# 5557    3
# 5558    3
# 5559    3
# 5560    3
# 5561    3
# 5562    3
# 5563    3
# 5564    3
# 5565    3
# 5566    4
# 5567    4
# 5568    3
# 5569    3
# 5570    3
# 5571    3
# Name: status, Length: 5572, dtype: int64

# %%
data['msg'].str.len()
# Out:
# 0       111
# 1        29
# 2       155
# 3        49
# 4        61
# 5       147
# 6        77
# 7       160
# 8       157
# 9       154
# 10      109
# 11      136
# 12      155
# 13      196
# 14       35
# 15      149
# 16       26
# 17       81
# 18       56
# 19      155
# 20       41
# 21       47
# 22       52
# 23       88
# 24       57
# 25      144
# 26       30
# 27      134
# 28       75
# 29       64
#        ...
# 5542     40
# 5543     38
# 5544    154
# 5545     45
# 5546     42
# 5547    160
# 5548     34
# 5549     87
# 5550     43
# 5551     51
# 5552     91
# 5553     27
# 5554     98
# 5555    153
# 5556     63
# 5557    273
# 5558     22
# 5559     66
# 5560     33
# 5561     70
# 5562     96
# 5563     19
# 5564     67
# 5565     12
# 5566    147
# 5567    160
# 5568     36
# 5569     57
# 5570    125
# 5571     26
# Name: msg, Length: 5572, dtype: int64

# %%
data['msg'][0]
# Out:
# 'Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...'

# %%
len(data['msg'][0])
# Out:
# 111

# %%
len(data['msg'][1])
# Out:
# 29

# %% [markdown]
# # Replace, Stop Word remove, Startswith, ends with

# %%
'I am learning Pandas'.replace('I am','You are')
# Out:
# 'You are learning Pandas'

# %%
data.head()
# Out:
#   status                                                msg
# 0    ham  Go until jurong point, crazy.. Available only ...
# 1    ham                      Ok lar... Joking wif u oni...
# 2   spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3    ham  U dun say so early hor... U c already then say...
# 4    ham  Nah I don't think he goes to usf, he lives aro...

# %%
data['msg'][3].replace('...', ' ')
# Out:
# 'U dun say so early hor  U c already then say '

# %%
data['msg'][3].replace('...', ' ').strip()
# Out:
# 'U dun say so early hor  U c already then say'

# %%
a, an the then

# %%
data['msg'][3].replace('so','').replace('then', '')
# Out:
# 'U dun say  early hor... U c already  say...'

# %%
data[data['msg'].str.startswith(' ')]
# Out:
#      status                                                msg
# 642     ham   said kiss, kiss, i can't do the sound effects...
# 2766    ham           and  picking them up from various points
# 3016    ham   &lt;#&gt;  mins but i had to stop somewhere f...
# 3032    ham   gonna let me know cos comes bak from holiday ...
# 3328    ham                what number do u live at? Is it 11?
# 3673    ham   came to look at the flat, seems ok, in his 50...
# 4026    ham                &lt;#&gt;  in mca. But not conform.
# 4266    ham   &lt;DECIMAL&gt; m but its not a common car he...
# 4418    ham   says that he's quitting at least5times a day ...

# %%
data['msg'][2766].strip()
# Out:
# 'and  picking them up from various points'

# %%
data[data['msg'].str.startswith('...')]
# Out:
#      status                                         msg
# 4838    ham  ....photoshop makes my computer shut down.
# 5408    ham                     ... Are you in the pub?

# %%
data[data['msg'].str.endswith('...')]
# Out:
#      status                                                msg
# 0       ham  Go until jurong point, crazy.. Available only ...
# 1       ham                      Ok lar... Joking wif u oni...
# 3       ham  U dun say so early hor... U c already then say...
# 22      ham  So ü pay first lar... Then when is da stock co...
# 38      ham                        Anything lor... U decide...
# 44      ham  Great! I hope you like your man well endowed. ...
# 66      ham  Today is "song dedicated day.." Which song wil...
# 70      ham     Wah lucky man... Then can save money... Hee...
# 74      ham                               U can call me now...
# 109     ham  I know! Grumpy old people. My mom was like you...
# 140     ham  Got c... I lazy to type... I forgot ü in lect....
# 153     ham                          Ok... Ur typical reply...
# 157     ham                        I'm leaving my house now...
# 190     ham  I jus reached home. I go bathe first. But my s...
# ...

# %% [markdown]
# # Filtering  Message with String

# %%
data.head(3)
# Out:
#   status                                                msg
# 0    ham  Go until jurong point, crazy.. Available only ...
# 1    ham                      Ok lar... Joking wif u oni...
# 2   spam  Free entry in 2 a wkly comp to win FA Cup fina...

# %%
mask = data['status'] == 'ham'
data[mask]
# Out:
#      status                                                msg
# 0       ham  Go until jurong point, crazy.. Available only ...
# 1       ham                      Ok lar... Joking wif u oni...
# 3       ham  U dun say so early hor... U c already then say...
# 4       ham  Nah I don't think he goes to usf, he lives aro...
# 6       ham  Even my brother is not like to speak with me. ...
# 7       ham  As per your request 'Melle Melle (Oru Minnamin...
# 10      ham  I'm gonna be home soon and i don't want to tal...
# 13      ham  I've been searching for the right words to tha...
# 14      ham                I HAVE A DATE ON SUNDAY WITH WILL!!
# 16      ham                         Oh k...i'm watching here:)
# 17      ham  Eh u remember how 2 spell his name... Yes i di...
# 18      ham  Fine if thats the way u feel. Thats the way ...
# 20      ham          Is that seriously how you spell his name?
# 21      ham    I‘m going to try for 2 months ha ha only joking
# ...

# %%
mask = data['status'] == 'spam'
data[mask]
# Out:
#      status                                                msg
# 2      spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 5      spam  FreeMsg Hey there darling it's been 3 week's n...
# 8      spam  WINNER!! As a valued network customer you have...
# 9      spam  Had your mobile 11 months or more? U R entitle...
# 11     spam  SIX chances to win CASH! From 100 to 20,000 po...
# 12     spam  URGENT! You have won a 1 week FREE membership ...
# 15     spam  XXXMobileMovieClub: To use your credit, click ...
# 19     spam  England v Macedonia - dont miss the goals/team...
# 34     spam  Thanks for your subscription to Ringtone UK yo...
# 42     spam  07732584351 - Rodger Burns - MSG = We tried to...
# 54     spam  SMS. ac Sptv: The New Jersey Devils and the De...
# 56     spam  Congrats! 1 year special cinema pass for 2 is ...
# 65     spam  As a valued customer, I am pleased to advise y...
# 67     spam  Urgent UR awarded a complimentary trip to Euro...
# ...

# %%
mask = data['msg'].str.contains('Sorry')
sorrymsg = data[mask]

# %%
len(sorrymsg)
# Out:
# 111

# %%
sorrymsg[sorrymsg['status'] == 'spam']
# Out:
#      status                                                msg
# 1699   spam  Free msg. Sorry, a service you ordered from 81...
# 2915   spam  Sorry! U can not unsubscribe yet. THE MOB offe...
# 3360   spam  Sorry I missed your call let's talk when you h...

# %%
mask = data['msg'].str.contains('later')
latermsg = data[mask]

# %%
latermsg
# Out:
#      status                                                msg
# 57      ham                 Sorry, I'll call later in meeting.
# 80      ham                             Sorry, I'll call later
# 85      ham  I call you later, don't have network. If urgnt...
# 94      ham  Havent planning to buy later. I check already ...
# 173     ham                  What time you coming down later?
# 223     ham                             Sorry, I'll call later
# 339     ham                             Sorry, I'll call later
# 408     ham  Hello! Good week? Fancy a drink or something l...
# 444     ham                             Sorry, I'll call later
# 450     ham                                  10 min later k...
# 464     ham                      Sorry, I'll call later ok bye
# 493     ham                   Sorry,in meeting I'll call later
# 537     ham  Probably gonna be here for a while, see you la...
# 590     ham                 I'm in a meeting, call me later at
# ...

# %% [markdown]
# # Spliting Text

# %%
mystr = 'Udemy Course : By Ankit Mistry :  Natural language Processing NLTK with Python'

# %%
mystr.split()
# Out:
# ['Udemy',
#  'Course',
#  ':',
#  'By',
#  'Ankit',
#  'Mistry',
#  ':',
#  'Natural',
#  'language',
#  'Processing',
#  'NLTK',
#  'with',
#  'Python']

# %%
mystr.split(':')
# Out:
# ['Udemy Course ',
#  ' By Ankit Mistry ',
#  '  Natural language Processing NLTK with Python']

# %%
mystr.split(maxsplit=5)
# Out:
# ['Udemy',
#  'Course',
#  ':',
#  'By',
#  'Ankit',
#  'Mistry :  Natural language Processing NLTK with Python']

# %%
data['msg'][0]
# Out:
# 'Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...'

# %%
data['msg'][0].split()
# Out:
# ['Go',
#  'until',
#  'jurong',
#  'point,',
#  'crazy..',
#  'Available',
#  'only',
#  'in',
#  'bugis',
#  'n',
#  'great',
#  'world',
#  'la',
#  'e',
#  'buffet...',
#  'Cine',
#  'there',
#  'got',
#  'amore',
#  'wat...']

# %%
data['msg'][0].split()[0]
# Out:
# 'Go'

# %%
data['msg'].str.split().str.get(0)
# Out:
# 0                        Go
# 1                        Ok
# 2                      Free
# 3                         U
# 4                       Nah
# 5                   FreeMsg
# 6                      Even
# 7                        As
# 8                  WINNER!!
# 9                       Had
# 10                      I'm
# 11                      SIX
# 12                  URGENT!
# 13                     I've
# 14                        I
# 15      XXXMobileMovieClub:
# 16                       Oh
# 17                       Eh
# 18                     Fine
# 19                  England
# 20                       Is
# 21                      I‘m
# 22                       So
# 23                      Aft
# 24              Ffffffffff.
# 25                     Just
# 26                      Lol
# 27                      Did
# 28                      I'm
# 29                    Ahhh.
#                ...
# 5542                 Armand
# 5543                      U
# ...

# %% [markdown]
# # Processing on column names

# %%
data.columns
# Out:
# Index(['status', 'msg'], dtype='object')

# %%
data.columns.str.len()
# Out:
# Int64Index([6, 3], dtype='int64')

# %%
data.columns.str.title()
# Out:
# Index(['Status', 'Msg'], dtype='object')

# %%
data.columns.str.upper()
# Out:
# Index(['STATUS', 'MSG'], dtype='object')

# %%
data.columns = data.columns.str.title()

# %%
data.head()
# Out:
#   Status                                                Msg
# 0    ham  Go until jurong point, crazy.. Available only ...
# 1    ham                      Ok lar... Joking wif u oni...
# 2   spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3    ham  U dun say so early hor... U c already then say...
# 4    ham  Nah I don't think he goes to usf, he lives aro...
