# %%
# %%HTML
# <style type="text/css">
#     table.dataframe td, table.dataframe th {
#         border-style: solid;
#         border-width: thin;
#     }
# </style>
# Out:
# <style type="text/css">
#     table.dataframe td, table.dataframe th {
#         border-style: solid;
#         border-width: thin;
#     }
# </style>

# %% [markdown]
# # Grouping Data

# %%
import pandas as pd

# %%
data = pd.read_csv('sales_data_sample-edited.csv')

# %%
data.head()
# Out:
#    QUANTITYORDERED  PRICEEACH    SALES   STATUS  MONTH_ID  YEAR_ID  \
# 0               30      95.70  2871.00  Shipped         2     2003
# 1               34      81.35  2765.90  Shipped         5     2003
# 2               41      94.74  3884.34  Shipped         7     2003
# 3               45      83.26  3746.70  Shipped         8     2003
# 4               49     100.00  5205.27  Shipped        10     2003
#
#    PRODUCTLINE              CUSTOMERNAME           CITY COUNTRY TERRITORY  \
# 0  Motorcycles         Land of Toys Inc.            NYC     USA       NaN
# 1  Motorcycles        Reims Collectables          Reims  France      EMEA
# 2  Motorcycles           Lyon Souveniers          Paris  France      EMEA
# 3  Motorcycles         Toys4GrownUps.com       Pasadena     USA       NaN
# 4  Motorcycles  Corporate Gift Ideas Co.  San Francisco     USA       NaN
#
#   DEALSIZE
# 0    Small
# 1    Small
# 2   Medium
# 3   Medium
# 4   Medium

# %%
data.columns
# Out:
# Index(['QUANTITYORDERED', 'PRICEEACH', 'SALES', 'STATUS', 'MONTH_ID',
#        'YEAR_ID', 'PRODUCTLINE', 'CUSTOMERNAME', 'CITY', 'COUNTRY',
#        'TERRITORY', 'DEALSIZE'],
#       dtype='object')

# %% [markdown]
# # Get Group Method

# %%
data.head(3)
# Out:
#    QUANTITYORDERED  PRICEEACH    SALES   STATUS  MONTH_ID  YEAR_ID  \
# 0               30      95.70  2871.00  Shipped         2     2003
# 1               34      81.35  2765.90  Shipped         5     2003
# 2               41      94.74  3884.34  Shipped         7     2003
#
#    PRODUCTLINE        CUSTOMERNAME   CITY COUNTRY TERRITORY DEALSIZE
# 0  Motorcycles   Land of Toys Inc.    NYC     USA       NaN    Small
# 1  Motorcycles  Reims Collectables  Reims  France      EMEA    Small
# 2  Motorcycles     Lyon Souveniers  Paris  France      EMEA   Medium

# %%
data['COUNTRY'].nunique()
# Out:
# 19

# %%
country_usa = data[data['COUNTRY'] == 'USA']
country_france = data[data['COUNTRY'] == 'France']
country_india = data[data['COUNTRY'] == 'India']

# %%
group_country = data.groupby('COUNTRY')

# %%
group_country.get_group('USA')
group_country.get_group('France')
#group_country.get_group('India')
# Out:
#       QUANTITYORDERED  PRICEEACH     SALES      STATUS  MONTH_ID  YEAR_ID  \
# 1                  34      81.35   2765.90     Shipped         5     2003
# 2                  41      94.74   3884.34     Shipped         7     2003
# 6                  29      86.13   2497.77     Shipped        11     2003
# 9                  41     100.00   4708.44     Shipped         1     2004
# 14                 45      92.83   4177.35     Shipped         7     2004
# 22                 21      34.91    733.11     Shipped         2     2005
# 34                 42     100.00   7290.36     Shipped        11     2003
# 43                 47     100.00  10172.70     Shipped        10     2004
# 56                 27     100.00   3307.77     Shipped         7     2003
# 60                 42     100.00   4695.60     Shipped        11     2003
# 68                 22     100.00   2904.44     Shipped         7     2004
# 70                 39      96.34   3757.26     Shipped         9     2004
# ...

# %%
type(group_country)
# Out:
# pandas.core.groupby.groupby.DataFrameGroupBy

# %% [markdown]
# # Size, First and Last Method

# %%
type(group_country.get_group('USA'))
# Out:
# pandas.core.frame.DataFrame

# %%
len(group_country.get_group('USA'))
len(group_country.get_group('France'))
# Out:
# 314

# %%
group_country.size()
# Out:
# COUNTRY
# Australia       185
# Austria          55
# Belgium          33
# Canada           70
# Denmark          63
# Finland          92
# France          314
# Germany          62
# Ireland          16
# Italy           113
# Japan            52
# Norway           85
# Philippines      26
# Singapore        79
# Spain           342
# Sweden           57
# Switzerland      31
# UK              144
# USA            1004
# dtype: int64

# %%
group_country.first()
# Out:
# 19

# %%
group_country.last()
# Out:
#              QUANTITYORDERED  PRICEEACH    SALES     STATUS  MONTH_ID  \
# COUNTRY
# Australia                 42      57.61  2419.62   Disputed         5
# Austria                   28      48.17  1348.76    Shipped         4
# Belgium                   37      45.86  1696.82    Shipped         7
# Canada                    33      51.32  1693.56    Shipped         8
# Denmark                   37      86.74  3209.38   Resolved        11
# Finland                   29     100.00  3978.51    Shipped         1
# France                    34      62.24  2116.16    Shipped         3
# Germany                   21      45.19   948.99    Shipped         9
# Ireland                   35     100.00  3986.50    Shipped         9
# Italy                     32      60.06  1921.92    Shipped         9
# Japan                     27      76.31  2060.37    Shipped        11
# Norway                    32      64.41  2061.12    Shipped         8
# ...

# %% [markdown]
# # Sum, Mean, Max, Min Method

# %%
data.head(3)
# Out:
#    QUANTITYORDERED  PRICEEACH    SALES   STATUS  MONTH_ID  YEAR_ID  \
# 0               30      95.70  2871.00  Shipped         2     2003
# 1               34      81.35  2765.90  Shipped         5     2003
# 2               41      94.74  3884.34  Shipped         7     2003
#
#    PRODUCTLINE        CUSTOMERNAME   CITY COUNTRY TERRITORY DEALSIZE
# 0  Motorcycles   Land of Toys Inc.    NYC     USA       NaN    Small
# 1  Motorcycles  Reims Collectables  Reims  France      EMEA    Small
# 2  Motorcycles     Lyon Souveniers  Paris  France      EMEA   Medium

# %%
group_country.get_group('USA').sum()['SALES']
# Out:
# 3627982.83

# %%
group_country.sum()['SALES']
# Out:
# COUNTRY
# Australia       630623.10
# Austria         202062.53
# Belgium         108412.62
# Canada          224078.56
# Denmark         245637.15
# Finland         329581.91
# France         1110916.52
# Germany         220472.09
# Ireland          57756.43
# Italy           374674.31
# Japan           188167.81
# Norway          307463.70
# Philippines      94015.73
# Singapore       288488.41
# Spain          1215686.92
# Sweden          210014.21
# Switzerland     117713.56
# UK              478880.46
# USA            3627982.83
# Name: SALES, dtype: float64

# %%
group_country.get_group('USA').mean()['SALES']
group_country.get_group('Australia').mean()['SALES']
# Out:
# 3408.773513513514

# %%
group_country.mean()['SALES']
# Out:
# COUNTRY
# Australia      3408.773514
# Austria        3673.864182
# Belgium        3285.230909
# Canada         3201.122286
# Denmark        3899.002381
# Finland        3582.412065
# France         3537.950701
# Germany        3556.001452
# Ireland        3609.776875
# Italy          3315.701858
# Japan          3618.611731
# Norway         3617.220000
# Philippines    3615.989615
# Singapore      3651.752025
# Spain          3554.640117
# Sweden         3684.459825
# Switzerland    3797.211613
# UK             3325.558750
# USA            3613.528715
# Name: SALES, dtype: float64

# %%
group_country.min()
# Out:
#              QUANTITYORDERED  PRICEEACH    SALES      STATUS  MONTH_ID  \
# COUNTRY
# Australia                 15      26.88   652.35    Disputed         1
# Austria                   10      42.67   640.05    Resolved         3
# Belgium                   10      45.86   881.40  In Process         1
# Canada                    20      35.35  1119.93     Shipped         4
# Denmark                   20      37.13  1146.50    Disputed         2
# Finland                   20      40.31   891.03     Shipped         1
# France                    11      29.21   482.13  In Process         1
# Germany                   20      31.20   948.99     Shipped         1
# Ireland                   20      52.82  1056.40     Shipped         2
# Italy                     15      28.88   577.60     Shipped         2
# Japan                     15      36.93   553.95     Shipped         1
# Norway                    20      34.36  1129.04     Shipped         1
# ...

# %%
group_country.max()['SALES']
# Out:
# COUNTRY
# Australia       9774.03
# Austria         9240.00
# Belgium         6804.63
# Canada          9064.89
# Denmark        10468.90
# Finland        10606.20
# France         11739.70
# Germany         8940.96
# Ireland         8258.00
# Italy           9160.36
# Japan          10758.00
# Norway          8844.12
# Philippines     7483.98
# Singapore      10993.50
# Spain          12001.00
# Sweden          7209.11
# Switzerland     6761.60
# UK             11886.60
# USA            14082.80
# Name: SALES, dtype: float64

# %% [markdown]
# # .agg method

# %%
data.head(3)
# Out:
#    QUANTITYORDERED  PRICEEACH    SALES   STATUS  MONTH_ID  YEAR_ID  \
# 0               30      95.70  2871.00  Shipped         2     2003
# 1               34      81.35  2765.90  Shipped         5     2003
# 2               41      94.74  3884.34  Shipped         7     2003
#
#    PRODUCTLINE        CUSTOMERNAME   CITY COUNTRY TERRITORY DEALSIZE
# 0  Motorcycles   Land of Toys Inc.    NYC     USA       NaN    Small
# 1  Motorcycles  Reims Collectables  Reims  France      EMEA    Small
# 2  Motorcycles     Lyon Souveniers  Paris  France      EMEA   Medium

# %%
group_country.agg('sum')
# Out:
#              QUANTITYORDERED  PRICEEACH       SALES  MONTH_ID  YEAR_ID
# COUNTRY
# Australia               6246   15449.14   630623.10      1345   370706
# Austria                 1974    4759.16   202062.53       383   110211
# Belgium                 1074    2887.31   108412.62       188    66138
# Canada                  2293    5957.05   224078.56       545   140274
# Denmark                 2197    5503.89   245637.15       444   126228
# Finland                 3192    7722.15   329581.91       485   184374
# France                 11090   25920.87  1110916.52      1960   629233
# Germany                 2148    5184.30   220472.09       525   124227
# Ireland                  490    1377.98    57756.43        81    32064
# Italy                   3773    9329.40   374674.31       868   226422
# Japan                   1842    4290.26   188167.81       254   104218
# Norway                  2842    7318.18   307463.70       710   170287
# ...

# %%
group_country.agg('sum')[['QUANTITYORDERED','SALES']]
# Out:
#              QUANTITYORDERED       SALES
# COUNTRY
# Australia               6246   630623.10
# Austria                 1974   202062.53
# Belgium                 1074   108412.62
# Canada                  2293   224078.56
# Denmark                 2197   245637.15
# Finland                 3192   329581.91
# France                 11090  1110916.52
# Germany                 2148   220472.09
# Ireland                  490    57756.43
# Italy                   3773   374674.31
# Japan                   1842   188167.81
# Norway                  2842   307463.70
# Philippines              961    94015.73
# Singapore               2760   288488.41
# Spain                  12429  1215686.92
# Sweden                  2006   210014.21
# Switzerland             1078   117713.56
# UK                      5013   478880.46
# USA                    35659  3627982.83

# %%
group_country.agg(['sum','mean'])[['QUANTITYORDERED','SALES']]
# Out:
#             QUANTITYORDERED                  SALES
#                         sum       mean         sum         mean
# COUNTRY
# Australia              6246  33.762162   630623.10  3408.773514
# Austria                1974  35.890909   202062.53  3673.864182
# Belgium                1074  32.545455   108412.62  3285.230909
# Canada                 2293  32.757143   224078.56  3201.122286
# Denmark                2197  34.873016   245637.15  3899.002381
# Finland                3192  34.695652   329581.91  3582.412065
# France                11090  35.318471  1110916.52  3537.950701
# Germany                2148  34.645161   220472.09  3556.001452
# Ireland                 490  30.625000    57756.43  3609.776875
# Italy                  3773  33.389381   374674.31  3315.701858
# Japan                  1842  35.423077   188167.81  3618.611731
# Norway                 2842  33.435294   307463.70  3617.220000
# Philippines             961  36.961538    94015.73  3615.989615
# ...

# %%
req = {'QUANTITYORDERED':'mean','SALES':'sum'}
group_country.agg(req)
# Out:
#              QUANTITYORDERED       SALES
# COUNTRY
# Australia          33.762162   630623.10
# Austria            35.890909   202062.53
# Belgium            32.545455   108412.62
# Canada             32.757143   224078.56
# Denmark            34.873016   245637.15
# Finland            34.695652   329581.91
# France             35.318471  1110916.52
# Germany            34.645161   220472.09
# Ireland            30.625000    57756.43
# Italy              33.389381   374674.31
# Japan              35.423077   188167.81
# Norway             33.435294   307463.70
# Philippines        36.961538    94015.73
# Singapore          34.936709   288488.41
# Spain              36.342105  1215686.92
# Sweden             35.192982   210014.21
# Switzerland        34.774194   117713.56
# UK                 34.812500   478880.46
# USA                35.516932  3627982.83
